# %%
pattern = '£ ?[0-9][0-9]?' # £ then SPACE-optional then digit then digit-optional

document = 'My eggs cost £ 3, bread cost £2, vodka cost £ 35'

# %%
import re

# %%
re.findall(pattern, document)
# Out:
# ['£ 3', '£2', '£ 35']

# %%
import pandas as pd

# %%
ti = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/diamler_17_jan/main/titanic.csv')
ti.sample(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 753         0       3  male  23.0      0      0   7.8958        S  Third  man
# 857         1       1  male  51.0      0      0  26.5500        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 753        True  NaN  Southampton    no   True
# 857        True    E  Southampton   yes   True

# %%
ti['ticket'] = "Ticket: " + ti['class'] + "; Price: $ " + ti['fare'].astype(str) + "; Port: " + ti['embark_town'] + ";"

# %%
ti[['class', 'fare', 'embark_town', 'ticket']].head(3)
# Out:
#    class     fare  embark_town  \
# 0  Third   7.2500  Southampton
# 1  First  71.2833    Cherbourg
# 2  Third   7.9250  Southampton
#
#                                               ticket
# 0   Ticket: Third; Price: $ 7.25; Port: Southampton;
# 1  Ticket: First; Price: $ 71.2833; Port: Cherbourg;
# 2  Ticket: Third; Price: $ 7.925; Port: Southampton;

# %%
pattern = '(First|Second)'

ti['class'].str.match(pattern)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890    False
# Name: class, Length: 891, dtype: bool

# %%
ti['ticket'].str.findall('([a-zA-Z]+[ :])').sample(10)
# Out:
# 330    [Ticket:, Price:, Port:]
# 9      [Ticket:, Price:, Port:]
# 410    [Ticket:, Price:, Port:]
# 523    [Ticket:, Price:, Port:]
# 470    [Ticket:, Price:, Port:]
# 488    [Ticket:, Price:, Port:]
# 34     [Ticket:, Price:, Port:]
# 729    [Ticket:, Price:, Port:]
# 428    [Ticket:, Price:, Port:]
# 59     [Ticket:, Price:, Port:]
# Name: ticket, dtype: object

# %%
ti['ticket'].str.findall('[A-Za-z]+').sample(10)
# Out:
# 355    [Ticket, Third, Price, Port, Southampton]
# 336    [Ticket, First, Price, Port, Southampton]
# 804    [Ticket, Third, Price, Port, Southampton]
# 243    [Ticket, Third, Price, Port, Southampton]
# 685     [Ticket, Second, Price, Port, Cherbourg]
# 45     [Ticket, Third, Price, Port, Southampton]
# 614    [Ticket, Third, Price, Port, Southampton]
# 329      [Ticket, First, Price, Port, Cherbourg]
# 31       [Ticket, First, Price, Port, Cherbourg]
# 852      [Ticket, Third, Price, Port, Cherbourg]
# Name: ticket, dtype: object

# %%
ti['ticket'].str.findall('[A-Za-z]+')
# Out:
# 0       [Ticket, Third, Price, Port, Southampton]
# 1         [Ticket, First, Price, Port, Cherbourg]
# 2       [Ticket, Third, Price, Port, Southampton]
# 3       [Ticket, First, Price, Port, Southampton]
# 4       [Ticket, Third, Price, Port, Southampton]
#                           ...
# 886    [Ticket, Second, Price, Port, Southampton]
# 887     [Ticket, First, Price, Port, Southampton]
# 888     [Ticket, Third, Price, Port, Southampton]
# 889       [Ticket, First, Price, Port, Cherbourg]
# 890      [Ticket, Third, Price, Port, Queenstown]
# Name: ticket, Length: 891, dtype: object

# %%
ti['ticket'].str.extract('(\$ [0-9]+\.[0-9]+)')
# Out:
#              0
# 0       $ 7.25
# 1    $ 71.2833
# 2      $ 7.925
# 3       $ 53.1
# 4       $ 8.05
# ..         ...
# 886     $ 13.0
# 887     $ 30.0
# 888    $ 23.45
# 889     $ 30.0
# 890     $ 7.75
#
# [891 rows x 1 columns]

# %%
ti['ticket'].str.extractall('(\$ [0-9]{3,}\.[0-9]+)')
# Out:
#                     0
#     match
# 27  0         $ 263.0
# 31  0      $ 146.5208
# 88  0         $ 263.0
# 118 0      $ 247.5208
# 195 0      $ 146.5208
# 215 0       $ 113.275
# 258 0      $ 512.3292
# 268 0      $ 153.4625
# 269 0      $ 135.6333
# 297 0        $ 151.55
# 299 0      $ 247.5208
# 305 0        $ 151.55
# 306 0      $ 110.8833
# 307 0         $ 108.9
# 311 0       $ 262.375
# 318 0      $ 164.8667
# 319 0         $ 134.5
# 325 0      $ 135.6333
# 332 0      $ 153.4625
# 334 0        $ 133.65
# 337 0         $ 134.5
# 341 0         $ 263.0
# 373 0      $ 135.6333
# 377 0         $ 211.5
# 380 0       $ 227.525
# 390 0         $ 120.0
# 393 0       $ 113.275
# 435 0         $ 120.0
# 438 0         $ 263.0
# 498 0        $ 151.55
# 505 0         $ 108.9
# 527 0      $ 221.7792
# 537 0       $ 106.425
# 544 0       $ 106.425
# 550 0      $ 110.8833
# 557 0       $ 227.525
# 581 0      $ 110.8833
# 609 0      $ 153.4625
# 659 0       $ 113.275
# 660 0        $ 133.65
# 679 0      $ 512.3292
# 689 0      $ 211.3375
# 698 0      $ 110.8833
# 700 0       $ 227.525
# 708 0        $ 151.55
# 716 0       $ 227.525
# 730 0      $ 211.3375
# 737 0      $ 512.3292
# 742 0       $ 262.375
# 763 0         $ 120.0
# 779 0      $ 211.3375
# 802 0         $ 120.0
# 856 0      $ 164.8667
